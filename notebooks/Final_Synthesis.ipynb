# %% [markdown]
# # CTM Final Synthesis: Offline Thought Analysis
#
# This notebook summarizes the key findings of the Continuous Thought Machines project.
# We investigate the structure of latent dynamics when sensory input is removed ('Offline Mode').

# %%
import sys
import os
sys.path.append('..')
from IPython.display import Image, display
from notebooks.make_final_plots import generate_plots

# Generate Plots
generate_plots()

# %% [markdown]
# ## 1. The Attractor Hypothesis
# Does the model settle into stable states?
# **Finding**: Yes. The velocity of the latent state decays towards zero, indicating convergence to an attractor basin.

# %%
display(Image(filename='notebooks/figures/final_convergence.png'))

# %% [markdown]
# ## 2. Offline Structure vs Randomness
# Is the offline thought learned?
# **Finding**: Yes. The Trained CTM exhibits significantly higher 'Replay Fidelity' (Closeness to Wake Manifold) than an Untrained baseline.

# %%
display(Image(filename='notebooks/figures/final_structure.png'))

# %% [markdown]
# ## 3. Replay and Difficulty
# How does problem difficulty affect thought?
# **Finding**: Strong negative correlation ($r \approx -0.87$). Harder problems cause the model to drift further from standard memory traces, implying a search process.

# %%
display(Image(filename='notebooks/figures/final_correlation.png'))
